# %%
import seaborn as sns
import matplotlib.pyplot as plt
import PyPDF2 as PyPDF2
import nltk
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize, sent_tokenize
import string
from rake_nltk import Rake
import pandas as pd


#================Summary===========================
mypdf = open("corpus/19660006049.pdf", mode='rb')
pdfReader = PyPDF2.PdfFileReader(mypdf)
text=''
for i in range(0,pdfReader.numPages):
    # creating a page object
    pageObj = pdfReader.getPage(i)
    # extracting text from page
    text=text+pageObj.extractText()
#tokenize
stopWords = set (stopwords.words("english"))
words = word_tokenize(text)
#frequency table
freqTable = dict()
for word in words:
    word = word.lower()
    if word in stopWords:
        continue
    if word in freqTable:
        freqTable[word] +=1
    else:
        freqTable[word] =1
#store sentences
sentences = sent_tokenize(text)
sentenceValue = dict()
for sentence in sentences:
    for word, freq in freqTable.items():
        if word in sentence.lower():
            if sentence in sentenceValue:
                sentenceValue[sentence] +=1
            else:
                sentenceValue[sentence] =1

sumValues = 0
for sentence in sentenceValue:
    sumValues += sentenceValue[sentence]
average = int(sumValues / len(sentenceValue))
#store sentences in summary
summary = ''
for sentence in sentences:
    if (sentence in sentenceValue) and (sentenceValue[sentence] > (3 * average)):
        summary += " " + sentence
print()
print("====This is the Summary===")
print(summary)
#================Keywords===========================
rake_nltk_var = Rake()
#remove punctuation
text = text.translate(str.maketrans('', '', string.punctuation))
#rake
rake_nltk_var.extract_keywords_from_text(text)
keyword_extracted = rake_nltk_var.get_ranked_phrases()
# Creating FreqDist with 20 most common tokens
all_fdist = nltk.FreqDist(keyword_extracted).most_common(20)

# Convert to Pandas for plotting
all_fdist = pd.Series(dict(all_fdist))

## Setting figure, ax into variables
fig, ax = plt.subplots(figsize=(10,30))

print()
print("===Keyword list===")
print(all_fdist)

#================Keywords Frequency plot===========================
print()
print("===Keyword Frequency plot===")
## Seaborn plotting using Pandas attributes + xtick rotation for ease of viewing
all_plot = sns.barplot(y=all_fdist.index, x=all_fdist.values, ax=ax)
plt.xticks(rotation=30);
# Out:
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# ====This is the Summary===
#  NATIONAL AERONAUTICS AND SPACE ADMINISTRATION
# 7echnical Report No, 32-845
# Translational and Rotational Motion of a Body
# Entering the Mars Atmosphere I J
# I
# I
# Peter Hans Feitis
# (PAGES)
# (NASA CR OR
# TMX OR AD NUMBER) ICATEGORYI
# GPO PRICE $
# CFSTI PRICE(S) $
# JET PROPULSION LABORATORY
# PASADENA, CALIFORNIA CALIFORNIA INSTITUTE OF TECHNOLOGY Hard copy (HC) o;?.Oo
# Microfiche (MF) *57>
# ff 853 July 65
# December 1, 1965 N ATlON AL AE RON AUT1 CS AN D SPACE A DM IN IST RATION
# Technical Report No. The virtual displacement components corresponding to
# the rotational degrees of freedom along the (xB, yB, z,) directions are dP
# = P dt = d$J (sin (3 sin 4) + d6' cos 4
# dQ = Q dt = d$ (sin e cos 4) - dB sin 4
# dR = R dt = d$ (cos 0) + d4 (1.7")
# -b
# respectively, The virtual work performed by the moment MA during the virtual displacement (dP, dQ, dR) is given
# by the scalar product dA
# = MA * (::) = -L C,A p i2 sin 8 d8/2 dR (1.8 ')
# Thus, the generalized forces corresponding to the rotational degrees of freedom are
# F+ = 0 Fd = 0 F, = -C,A p z2 L sin el2
# Substitution into Equations (1.2 ') results in the equations of motion (4.44- 4.46) of Section IV.
#
# ===Keyword list===
# motion                  14
# respect                 14
# given                   13
# sphere                  11
# sphere entering         10
# center                  10
# function                10
# altitude                 9
# 32845                    9
# gravity                  8
# atmosphere               7
# stratosphere             7
# assume                   7
# troposphere              6
# jpl technical report     5
# density                  5
# rotational motion        5
# x                        5
# sphere ’                 5
# assumed                  5
# dtype: int64
#
# ===Keyword Frequency plot===

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import PyPDF2 as PyPDF2
import nltk
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize, sent_tokenize
import string
from rake_nltk import Rake
import pandas as pd


#================Summary===========================
mypdf = open("corpus/19740019229.pdf", mode='rb')
pdfReader = PyPDF2.PdfFileReader(mypdf)
text=''
for i in range(0,pdfReader.numPages):
    # creating a page object
    pageObj = pdfReader.getPage(i)
    # extracting text from page
    text=text+pageObj.extractText()
#tokenize
stopWords = set (stopwords.words("english"))
words = word_tokenize(text)
#frequency table
freqTable = dict()
for word in words:
    word = word.lower()
    if word in stopWords:
        continue
    if word in freqTable:
        freqTable[word] +=1
    else:
        freqTable[word] =1
#store sentences
sentences = sent_tokenize(text)
sentenceValue = dict()
for sentence in sentences:
    for word, freq in freqTable.items():
        if word in sentence.lower():
            if sentence in sentenceValue:
                sentenceValue[sentence] +=1
            else:
                sentenceValue[sentence] =1

sumValues = 0
for sentence in sentenceValue:
    sumValues += sentenceValue[sentence]
average = int(sumValues / len(sentenceValue))
#store sentences in summary
summary = ''
for sentence in sentences:
    if (sentence in sentenceValue) and (sentenceValue[sentence] > (2 * average)):
        summary += " " + sentence
print()
print("====This is the Summary===")
print(summary)
#================Keywords===========================
rake_nltk_var = Rake()
#remove punctuation
text = text.translate(str.maketrans('', '', string.punctuation))
#rake
rake_nltk_var.extract_keywords_from_text(text)
keyword_extracted = rake_nltk_var.get_ranked_phrases()
# Creating FreqDist with 20 most common tokens
all_fdist = nltk.FreqDist(keyword_extracted).most_common(20)

# Convert to Pandas for plotting
all_fdist = pd.Series(dict(all_fdist))

## Setting figure, ax into variables
fig, ax = plt.subplots(figsize=(10,30))

print()
print("===Keyword list===")
print(all_fdist)

#================Keywords Frequency plot===========================
print()
print("===Keyword Frequency plot===")
## Seaborn plotting using Pandas attributes + xtick rotation for ease of viewing
all_plot = sns.barplot(y=all_fdist.index, x=all_fdist.values, ax=ax)
plt.xticks(rotation=30);
# Out:
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# ====This is the Summary===
#  The Texas A&M University
# Department of Physics
# College Station, Texas 77843
# Semi-Annual Report
# RADIATIVE TRANSFER IN REALISTIC PLANETARY ATMOSPHERES
# Date of Issue: March 31, 1974
# Grant No. NGR 44-001-117
# Principal Investigators: Gilbert N. Plass
# George W. Kattawar
# N74-27342 (NAS AC-i 38 601 -ADf-vE- TRANSFER IN
# (NAS-CR -1 38601) RADII'TVE
# REALISTIC PLANETARY A~IOSPHERES
# Semiannual Report, 1 t 1973 -1 Apr Uclas
# 1974 (Texas A&M Tniv. ),/ 7 p HC $.0 SCL 03 G3/30 4119CSCL 03B G3/30' 1196
# -1-
# Semi-Annual Report
# October 1, 1973 -April 1, 1974
# During the past six months we have completed an article on the in-
# terior radiances within an optically deep absorbing medium scattering
# according to the Haze L phase function. Degree and Plane of Polarization of Multiple Scattered Light. Degree and Plane of Polarization of Multiple Scattered Light. Interior Radiances in Optically Deep Absorbing Media. Interior Radiances in Optically Deep Absorbing Media. Degree and Plane of Polarization of Multiple Scattered Light. Degree and Plane of Polarization of Multiple Scattered Light. Interior Radiances in Optically Deep Absorbing Media. Interior Radiances in Optically Deep Absorbing Media. Interior Radiances in Optically Deep Absorbing Media.
#
# ===Keyword list===
# results                                                                                    5
# quantitative spectroscopy                                                                  4
# plane                                                                                      4
# calculations                                                                               4
# polarization                                                                               4
# used                                                                                       4
# calculated                                                                                 4
# matrix operator method                                                                     3
# single scattering albedo                                                                   3
# radiative transfer                                                                         3
# journal                                                                                    3
# radiance                                                                                   3
# color                                                                                      3
# calculate                                                                                  3
# optically deep absorbing media ii rayleigh scattering gilbert n plass george w kattawar    2
# twilight zone charles n adams gilbert n plass                                              2
# maritime haze george w kattawar gilbert n plass                                            2
# homogeneous cloud layers george w kattawar                                                 2
# haze l george w kattawar                                                                   2
# optically deep absorbing media                                                             2
# dtype: int64
#
# ===Keyword Frequency plot===

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import PyPDF2 as PyPDF2
import nltk
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize, sent_tokenize
import string
from rake_nltk import Rake
import pandas as pd


#================Summary===========================
mypdf = open("corpus/19810023782.pdf", mode='rb')
pdfReader = PyPDF2.PdfFileReader(mypdf)
text=''
for i in range(0,pdfReader.numPages):
    # creating a page object
    pageObj = pdfReader.getPage(i)
    # extracting text from page
    text=text+pageObj.extractText()
#tokenize
stopWords = set (stopwords.words("english"))
words = word_tokenize(text)
#frequency table
freqTable = dict()
for word in words:
    word = word.lower()
    if word in stopWords:
        continue
    if word in freqTable:
        freqTable[word] +=1
    else:
        freqTable[word] =1
#store sentences
sentences = sent_tokenize(text)
sentenceValue = dict()
for sentence in sentences:
    for word, freq in freqTable.items():
        if word in sentence.lower():
            if sentence in sentenceValue:
                sentenceValue[sentence] +=1
            else:
                sentenceValue[sentence] =1

sumValues = 0
for sentence in sentenceValue:
    sumValues += sentenceValue[sentence]
average = int(sumValues / len(sentenceValue))
#store sentences in summary
summary = ''
for sentence in sentences:
    if (sentence in sentenceValue) and (sentenceValue[sentence] > (1 * average)):
        summary += " " + sentence
print()
print("====This is the Summary===")
print(summary)
#================Keywords===========================
rake_nltk_var = Rake()
#remove punctuation
text = text.translate(str.maketrans('', '', string.punctuation))
#rake
rake_nltk_var.extract_keywords_from_text(text)
keyword_extracted = rake_nltk_var.get_ranked_phrases()
# Creating FreqDist with 20 most common tokens
all_fdist = nltk.FreqDist(keyword_extracted).most_common(20)

# Convert to Pandas for plotting
all_fdist = pd.Series(dict(all_fdist))

## Setting figure, ax into variables
fig, ax = plt.subplots(figsize=(10,30))

print()
print("===Keyword list===")
print(all_fdist)

#================Keywords Frequency plot===========================
print()
print("===Keyword Frequency plot===")
## Seaborn plotting using Pandas attributes + xtick rotation for ease of viewing
all_plot = sns.barplot(y=all_fdist.index, x=all_fdist.values, ax=ax)
plt.xticks(rotation=30);
# Out:
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# ====This is the Summary===
#  ALTHOUGH IT IS RECOGNIZED THAT CERTAIN PORTIONS ARE ILLEGIBLE, IT IS BEING RELEASED IN THE INTEREST OF MAKING AVAILABLE AS MUCH INFORMATION AS POSSIBLE V
# E. Wade
# nvestigator
# 0.
# esearch Laboratory
# ate University
# trical Engineering
# Mississippi 39762^(tl^SA -Cli•ta13tl5) 	bA.uu y^rpJl^y• Ctu^.U.&I
# TSCNMOL0GV Wuartariy Pto91C OSO iioport, 13
# Jul. 17 p
# dC A42 as A01 	 CSCL 09A Q.
# V
# OQUAIRITERLY REPORT11u ^-J-,-j
# Uucl is
# 31 374114
# I^%I-,%,July 13, 1')79 - October 13, 1979
# Contra t NASA-33448
# (NASA -CR-1(,1345) 	 HIGH D--NSI'IY C:FC01TTECHNOLOGY Quarterly Rprort, 13 Jul. * Mississippi 	 anclasslat.. 	 17 p 	a 31 ==SNOWT^DF.NSTt'Y
# C I#QQVT RC.NLIOI".Y
# OCT 1 91
# RECEI VED
# kw, STI FACWTY
# &GEM WL
# C..,	cri
# ^f^^9!QUARTERLY REPORT
# July 13, 1979 - October 1-'
# Contract NAS8- 33448
# HIGH DENSITY
# CTRCUIT TECHNOLOGY
# j
# Prepared for
# George C. Marshall Space `light Center
# Marshall Space Flight Center, Alabama 15312
# by
# Thomas E. Wade
# Principal Investigator
# 1
# Microelectronics Pesearch LaboraLory
# Mississippi State University
# Department of Electrical Engineering
# Mississippi State, Mississippi 1976?TABLE OF CONTENTS
# Page
# I. 11iI.INTRODUCTION
# Progress has been accomplished in all of the proposed areas as
# listed under the Scope of Work, Exhibit A, Contract NAS8-33448. Some delays have been experienced due to metal deposition equipment
# malfunctions and start-up procedures associated with the Mississippi
# State Microelectronics Research Laboratory. It is felt that many
# of these problems have been eliminated to the extent that normal
# progress will be rendered during the next contract quarter. In accordance with the contracts "Report Requirements" section
# which states "quarterly reports shall be in narrative form, and
# brief and informal in content", the following research areas of
# emphasis will be addressed. MULTI-LEVEL METAL TECHNIC
# This sr.udy is a continuation of last years NASA contact effort
# (J. D. Trotter, T. E. Wade, J. D. Gassaway, "Trends and Techniques
# for Space Base Electronics", NASA Contract NAS8-26749, June, 1979). In addition to heat treatment studies and the use of phosphosili--
# sate glass as a dielectric (T. E. Wade, Special Report, "Post Heat
# Treatment Effects on Double Layer Metal Structuree for VLSI Appli-
# cations," NASA Contract NAS8-26749, November, 1979), se, ►eral wafers
# having first level patterned metal were sent to the West Coast for
# processing. silicon dioxide (vapox),2
# silicon nitride and polyimide (GAF and Hitachi versions) after
# which via's were realized as per the M.S.F.C. Prior to depositing the second layer metal,
# the wafers will have to be back-spuitered in-situ to eliminate the
# Al203 present on the first layer metal in the via's. using their new back-sputtering capability (to be installed within
# the next quarters effort)'. During the first quarter, polyimide materials have been
# received from two different companies, Hitachi. personnel (thanks to Mr.. Donald Routh) while
# additional materials and information have been ordered from the
# company. Dupont has forwarded their polyimide (PI-2550) and
# thinner, but their adhesion promoter has been back logged. Initial
# studies (i.e., -endors info, literature and preliminary experi-
# ments) indicate the Hitachi P. I.Q. Hopefully, before the termination of this contract, Mississippi
# State's Microelectronics Research Laboratory will have the capability
# of depositing silicon nitride as a dielectric using the Unipak VIII
# Rpitaxial Reactor. A problem experienced during the firs ,: quarter of this contract
# was with the metal deposition system. A short in the d.c. sputter
# gun resulting; from an accumulation of aluminum on oucc side of the
# gun caused the gun's power supply to fail. Attempts to repair this
# by local technicians were unsuccessful (due to inability to monitor
# fsequential timing of power SCRs-and poor documentation), and hence
# the 2.5 Kw power supply had to be sent- to the {Jest Coast for repair. were supplied to those
# locations in tbs: laboratory where required in some what of a tem-
# porary arrangement. Beginning with this academic school year, all
# temporary lines were dismantled and replaced with permanent lines
# to our gas bottle closets with all stainless steel runs placed in
# w:
# the ceiling, etc. The complete replumbing activity should be com-
# pleted in the near future, depending on the receipt of parts nowIII. METAL LIFT-OFF TECHIZ ULS
# A review of the literature indicates that sputtered aluminuun
# films may be successfully patterned using the lift-off technique
# provided the vubstrate surface temperature remains low (<100'C)
# and the atmospheric pressure in the chamber is relatively high at
# the time of sputtering. if these conditions are met, aluminum films
# which exceed the photoresist in thickness can be successfully
# deposited without reductAon in pattern width. Also, the slope of
# the side walls of metallized aluminum patterns is controlled by
# the argon pressure during sputtering in the following manner. As illustrated below, the aluminum films grows perpendicular Co the
# sidewalls of the photoresist pattern and the substrate surface,
# -DC ;-k
# Mf filmZ§M.Weraje.\\ \ \\ ^ ^ -3rmc^ ►ohofoty
# ..5c: ^s-a
# C z or S'i
# respectively. The films contact each other near the photoresist
# pattern edges, but do not fuse together since they have different
# growth directions (at low temperatures), resulting in a microcrack
# formation. (1) the metal deposition rata on the photoresist sidewalls, Vp
# and (2) the deposition rate: normal to the substrate, V s , and can
# be exprvnsed us
# V
# 8 eon 1 VB
# p
# At low argon pressure in the chamber, V s is large and V  is
# small since most deposited atoms fall on the substrate surface
# (directly f.om the target). At least three additional metal lift-off techniques have been
# researched as reported in the literature (i.e. DRY PROCESSING GgUIPt4CNT EVALUATION
# With the assistance of former colleagues who are presently
# located on the West Coast, a list of primary vendors for dry
# processing equipment have been compiled and is attached to this
# report. Letters of inquiry and/or telephone contact have been
# forwarded to most companies on this list, several of which have
# responded with equipment literature and/or specification sheets. It is anticipated that after reviewal of the vendors literature,
# equipment can be identified which has the potential of meeting
# the needs of H.S.F.C. 's objectives, and at a later date aW
# 6
# demonstration and evaluation of such equipment can be undertaken. A prototype parallel plate plasma etch machine has been
# identified for either purchase at a much reduced price or donated
# to the Microelectronics Research Laboratory at M.S.U. It is hoped that delivery and installatlor ► of this
# etcher is such that experimental studies may be reported during
# this contract period. A considerable amodnt of material has been collected via
# personal contacts, library stud3ea, vendor's info, etc. This material will be reviewed
# and essential portions presented in the final report of this contract. 'RENDS IN 'VLSI FABRICATION TECIR'l $S
# An extensive study is underway to evaluate present and future
# trends. C.Processes as related to fabrication, as low pressure C.V.11,
# high pressure oxidation, resist materials, etc. D.Also, proposed materials and areas as metal silicide inter-
# connection technology, refractory metal gate processes,
# laser annealing (of ion-implanted or lattice damage, of
# amorphous or poly, etc.)' This past summer, two Kasper 1.00 •Kev ion implantors (one will be
# used for parts) were received and installation of one of these is
# presently underway. As mentioned early, it is hoped that the
# parallel plate plasma etcher can be acquired this year and used
# for this contract effort. A new full time laboratory fabrication technician has been
# hired and reported to work this month (October, 1979). Mrs. Becky
# tiamiltan has had fifteen years of processing experience in major
# semiconductor companies on the West Coast. VII.PROPOSED WORK FOR NEXT QUARTER
# It is anticipated that for next quarter, a continuation of
# began this quarter will be undertaken with considerable
# emphasis on laboratory experimental studies as related to
# le. Rack
# red supplies should be forthcoming in the next few weeks and
# laboratory facilities should also be in working order.8
# Trips to the International Electron Devices Meeting in Waahin8ton
# D.C. are planned, as well as possible ., trip to the West Coast to
# attend the Materials Research Corporations conference and school
# on Sputtering and Plasma Etching. PROBLEMS ARF %S
# As indicated, this quarters problems have been experienced with
# failures of the metallization system power supply and sputter gun. Alao, replumbing of 1nboratory San runs
# and alterations in equipment location have hampered laboratory
# experimentation in addition to long delay:; in rwceiving orderwd
# supplies (as Shipley photo resist, Dupont pnlyimide coupler,
# sputter gun holder., etc.). Tegrl, Inc.
# 528 Weddell Dr.
# Sunnyvale, California 94086
# (408)744-0872 	 Contact: Phil Crabtree
# Barrel and "in-line" parallel plate reactors both with
# end point detectors. IFE
# 2920 San XsI,1ro Way
# Santa Clara, Californin 95051
# (408)727-2360 	 Contact: Ken Scow
# Barrel and small parallel plate reactors also, an
# "in-line" 5 wafer system
# 3.D-W Industries (part of Kasper Instruments)
# 844 Del Rey
# Sunnyvale, California 94086
# (408)733-9800 	 Contact: Berl Bragg
# Parallel Plate batch system only4.Dionex (Formerly I.P.C.) 3115^ San Benito Street
# Hayward, California 94544
# (415)489-3030 	 Contact: Wayne Landman
# Parallel plate batch and barrel oquipmont
# 5.Applied Materials
# 3050 Bower. Avenue
# Santa Clara, California 94051
# (408)249-5555 	 Contact: Steve Corlett
# Plasma nitride deposition and etch aystems. Systems
# 23780 Walsh Avenue
# Santa Clara, California 05050
# (408)984-230G 	 Contact: Clint Graves
# Planar Aluminum, poly, nitride batch etchers4
# R. Reactive YON Etchers
# Varian
# 375 nistel Circle
# Los Altos, California 94022
# (415)966-1110
# Still, in development
# C. ION Beam MillingContact: Louis Kunz
# VEECO
# 599 N. Mathilda Avenue, 'Suite 140
# Sunnyvale, California 94086
# (608)732-2330
# In production
# A. (see above)
# 3.AMT (see above)
# 4.Pacific-Western Systems
# 855 Maude Avenue
# Mountain View, California
# (415)961.-8861 	 Contact: Norm Lewis
# Both nitride and oxide plasma deposition10
# R. Low Pressure CVD Vendors (Oxide. Poly)
# 1.Thermco
# 1465 N. Sataula Street
# Orange, California 92668
# (714)639-2340
# 2.Advance Crystal Science
# 2995 Copper Road
# Santa Clara, California 95051
# (40..)733-3633 	 Contact: Roger McKinley
# 3.Tylan Corporation
# 4203 Spencer Street
# Torrance, CA 90503
# 4.ASM/America . 2328A Walsh Avenue
# Santa Clara, California 95050
# (408)727-2323 	 Contact: Ing-tiurie Helmer
# F. Sputter Deposition System AL ;, Al, Al/Si, Al/Si/Cu,
# Silleides, etc. 1.Perkin-Elmer
# 361 Wallow Street
# San Jose, California 95110
# (408)249-5540 	Ext. California 94086
# (408)733-9823
# 3.Varian (see above)
# 4.MRC
# 1101 San Antonio Road
# Mt. View, California 94040
# (415)964-7272Contact: David Tam
# Contact: Ed Wilder
# Contact: Dick Walker11,
# S1
# i
# i:w
# QUARTERLY
# FINANCIAL REPORT
# FOR
# NASA Contract NAS8-334!i8
# July 13, 1979 - October 13, 1979
# Prepared for
# George C. Marshall Space Flight Center
# Marshall Space Flight Center, Alabama 35812
# Submitted by
# Thomas E. Wade
# Principal Investigatorf
# v;
# i
# i a.! UItl
# Nu
# C
# •r
# Nt°rii^
# W^a
# r y ^
# a I n: ^
# ^ O ^
# ^y r
# :J.
# t ►M H
# ^ v
# e`
# o^
# h
# ON
# MN w
# rl
# N h
# LA
# IpoMti
# ^H
# H
# HWTH
# UQn►al	•	 rn C,	ca
# t.oi^ 	 rii	n
# C1 P.
# P:	t[1	 .•1
# n.	 yr
# to Vd
# p :ac 	 cca
# (+.Ooir	 rh1!^
# ^J
# C9 N	f
# 0-4	1
# f''	t1
# ^^ CJ
# 0 U
# 0 I.r
# nc.J
# 1
# ^	 r
# fI
# ^. c:	 ul
# W •-/	 f 1	r11	7
# .f,-- T.-
# ^o
# oI	 o.n4'J
# CA
# ..112
# i
# O	 r	 C	 n	 N	 a
# in	 1	 1^	 n	,rw
# ^	cy	 Cl
# o	 o	c	 C°,
# C)	 ^f
# M	 ^I	 h	7J	«1w	 w	 w
# N	 M
# 1_..._1.._.._1 ._.1—
# QI	I	I	I	I	II QI	l	0
# :n
# 1-+
# N
# i
# W	 A:
# i1	 `J
# M	 Ca	 •,as	^	 N	t T..	 P.	 N	 '	 a! 1^1	 1	•	 Sal	 r:,	 h+	 .+	 f•
# ,r1	 11	 f 1	 1.3	 ^	 U	 :1:	 ^:a
# ..J
# 'V NN J.JO OF-^ C) V
# O p. f)M rf1u
# )nry n)
# (')':	tt) N ^ ^ r'1a v►a
# z13
# .y
# W
# uM O
# iO7 ,Nry
# v'^+Oo0
# ^Nww
# u
# cu
# ut9 c/1
# VA
# vH H .^
# 1• F N
# SO7 U
# t+1
# a
# N Ln
# H M[IA4j
# ^ r.
# J^ ^ H ^ t•1 •^7t
# CoG^ (^	("'^	ti•
# ..	 Cairk
# MIn^^
# 00 rn
# V)
# t ;^
# h, nOJ
#  to J ' ; -? 6-4	1-4 O
# rn1ul ,n
# ah^
# s' G^i0000^t
# H >C ^
# ca
# ON
# nONyw^ wrn
# rn^
# a F,
# N y th t^1n.-J aJ.rr
# O	 a^	,^	 '^	 rn	 <n
# O	^	 yw	a
# N
# V b 	N
# rO	 ,uJ	O	nj
# 3t	 ^' d	t	d	.4	t^
# a	to	 ►%	 u u Q4 •r4 	 a
# M	O	V) U)	 N	•r4
# '1. w 	$	 b W	b	 a	.c	 •	 N+4 	 U	 F•	 , a
# VJ	r A. 	 f	 rr	 ^^^Ufill	P,
# (+	W r4	rV	 en	 7	 in	(a	 ^
# LAI
# O
# A
# ^	 M	V__ - t._-....A_... _.
# ns
# , • 1
# I,Vn
# N
# t •1
# W^J
# laW
# I.1•7
# J
# U
# v
# N•
# CJ
# h•14
# • IL 1ta71 . II
# O1-4
# f-+to
# W
# o
# raG
# a f aQ1 MLr)
# 01.-tMo
# 1,rrrnLnco
# xV
# WrM I-+	O f"r1 t. .-I00 C,OCR►,^J71t.^
# C2, whroox
# N(y
# r tW11
# .
#
# ===Keyword list===
# west coast                              5
# wafers                                  4
# anticipated                             4
# related                                 4
# received                                4
# n                                       3
# sputtering                              3
# reported                                3
# addition                                3
# microelectronics research laboratory    2
# 1                                       2
# w                                       2
# next quarter                            2
# also                                    2
# machine                                 2
# material                                2
# emphasis                                2
# well                                    2
# used                                    2
# undertaken                              2
# dtype: int64
#
# ===Keyword Frequency plot===

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import PyPDF2 as PyPDF2
import nltk
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize, sent_tokenize
import string
from rake_nltk import Rake
import pandas as pd


#================Summary===========================
mypdf = open("corpus/19880018793.pdf", mode='rb')
pdfReader = PyPDF2.PdfFileReader(mypdf)
text=''
for i in range(0,pdfReader.numPages):
    # creating a page object
    pageObj = pdfReader.getPage(i)
    # extracting text from page
    text=text+pageObj.extractText()
#tokenize
stopWords = set (stopwords.words("english"))
words = word_tokenize(text)
#frequency table
freqTable = dict()
for word in words:
    word = word.lower()
    if word in stopWords:
        continue
    if word in freqTable:
        freqTable[word] +=1
    else:
        freqTable[word] =1
#store sentences
sentences = sent_tokenize(text)
sentenceValue = dict()
for sentence in sentences:
    for word, freq in freqTable.items():
        if word in sentence.lower():
            if sentence in sentenceValue:
                sentenceValue[sentence] +=1
            else:
                sentenceValue[sentence] =1

sumValues = 0
for sentence in sentenceValue:
    sumValues += sentenceValue[sentence]
average = int(sumValues / len(sentenceValue))
#store sentences in summary
summary = ''
for sentence in sentences:
    if (sentence in sentenceValue) and (sentenceValue[sentence] > (2 * average)):
        summary += " " + sentence
print()
print("====This is the Summary===")
print(summary)
#================Keywords===========================
rake_nltk_var = Rake()
#remove punctuation
text = text.translate(str.maketrans('', '', string.punctuation))
#rake
rake_nltk_var.extract_keywords_from_text(text)
keyword_extracted = rake_nltk_var.get_ranked_phrases()
# Creating FreqDist with 20 most common tokens
all_fdist = nltk.FreqDist(keyword_extracted).most_common(20)

# Convert to Pandas for plotting
all_fdist = pd.Series(dict(all_fdist))

## Setting figure, ax into variables
fig, ax = plt.subplots(figsize=(10,30))

print()
print("===Keyword list===")
print(all_fdist)

#================Keywords Frequency plot===========================
print()
print("===Keyword Frequency plot===")
## Seaborn plotting using Pandas attributes + xtick rotation for ease of viewing
all_plot = sns.barplot(y=all_fdist.index, x=all_fdist.values, ax=ax)
plt.xticks(rotation=30);
# Out:
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# ====This is the Summary===
#  NASA
# Technical
# Paper
# 2847
# September 1988 NASA
# Technical Paper
# 2847
# National Aeronautics and Space Administration
# Scientific and Technical Information Division More on Exact State Reconstruction in Deterministic Digital Control Systems
# Michael E. Polites
# George C. Marshall Space Flight Center Marshall
# Space Flight Center, Alabama TABLE OF CONTENTS '
# Page I
# . Consequently, if one is given the plant in ~i~ure 1 and modifies it to conform to Figure 3, he can -
# exactly reconstruct the state of the plant without adding any new states, eigenvalues, or dynamics to it, since the plant equation (18) for the system in Figure 3 is identical to the plant equation
# (1) for the plant in PLANT --------------- IDEAL STATE RECONSTRUCTOR r T ......................... 1
# Figure 3. NASA TP-2757, George C. Marshall Space Flight Center, Huntsville, Alabama, August 1987. .
# Polites, M. E.: Further Developments in Exact State Reconstruction in Deterministic Digital Control Systems. DISTRIBUTION STATEMENT
# Digital Control Systems Multirate Sampling State Estimation State Reconstruction Unclassified - Unlimited Subject Category: 31
# - -
# For sale by Natlonal Technical Idonnation Service, Springfield, ~kinin 22 16 1 I
# 19.
#
# ===Keyword list===
# ideal state reconstructor    19
# system                       19
# special form                 16
# plant                        16
# number                       14
# given                        13
# output                       10
# ct                            9
# true state                    7
# discrete state equations      6
# figure 3                      6
# general form                  6
# state                         6
# process                       6
# e                             5
# n                             5
# seconds                       5
# follows                       5
# chosen                        5
# zeroorderhold                 5
# dtype: int64
#
# ===Keyword Frequency plot===

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import PyPDF2 as PyPDF2
import nltk
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize, sent_tokenize
import string
from rake_nltk import Rake
import pandas as pd


#================Summary===========================
mypdf = open("corpus/19820014033.pdf", mode='rb')
pdfReader = PyPDF2.PdfFileReader(mypdf)
text=''
for i in range(0,pdfReader.numPages):
    # creating a page object
    pageObj = pdfReader.getPage(i)
    # extracting text from page
    text=text+pageObj.extractText()
#tokenize
stopWords = set (stopwords.words("english"))
words = word_tokenize(text)
#frequency table
freqTable = dict()
for word in words:
    word = word.lower()
    if word in stopWords:
        continue
    if word in freqTable:
        freqTable[word] +=1
    else:
        freqTable[word] =1
#store sentences
sentences = sent_tokenize(text)
sentenceValue = dict()
for sentence in sentences:
    for word, freq in freqTable.items():
        if word in sentence.lower():
            if sentence in sentenceValue:
                sentenceValue[sentence] +=1
            else:
                sentenceValue[sentence] =1

sumValues = 0
for sentence in sentenceValue:
    sumValues += sentenceValue[sentence]
average = int(sumValues / len(sentenceValue))
#store sentences in summary
summary = ''
for sentence in sentences:
    if (sentence in sentenceValue) and (sentenceValue[sentence] > (3 * average)):
        summary += " " + sentence
print()
print("====This is the Summary===")
print(summary)
#================Keywords===========================
rake_nltk_var = Rake()
#remove punctuation
text = text.translate(str.maketrans('', '', string.punctuation))
#rake
rake_nltk_var.extract_keywords_from_text(text)
keyword_extracted = rake_nltk_var.get_ranked_phrases()
# Creating FreqDist with 20 most common tokens
all_fdist = nltk.FreqDist(keyword_extracted).most_common(20)

# Convert to Pandas for plotting
all_fdist = pd.Series(dict(all_fdist))

## Setting figure, ax into variables
fig, ax = plt.subplots(figsize=(10,30))

print()
print("===Keyword list===")
print(all_fdist)

#================Keywords Frequency plot===========================
print()
print("===Keyword Frequency plot===")
## Seaborn plotting using Pandas attributes + xtick rotation for ease of viewing
all_plot = sns.barplot(y=all_fdist.index, x=all_fdist.values, ax=ax)
plt.xticks(rotation=30);
# Out:
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# ====This is the Summary===
#  ‘r“ . . . .
# A General Solution
# to the Hidden-Line
# Problem NASA
# Reference
# Pubiication
# 1085
# March 1982
# David R. Hedgley, Jr. NASA
# RP
# 1085
# c.1 NASA
# Reference
# Publication
# 1085
# 1982
# Natlonal Aeronautics
# and Space AdmInIstratIon
# Scientific and Technical
# information Branch TECH LIBRARY KAFB, NM
# A General Solution
# to the Hidden-Line
# Problem
# David R. Hedgley, Jr.
# Ames Research Center
# Dryden Flight Research Facility
# Edwards, California A GENERAL SOLUTION TO THE HIDDEN-LINE PROBLEM
# David R. Hedgley , Jr.
# Ames Research Center
# Dryden Flight Research Facility
# INTRODUCTION
# The requirement for computer-generated perspective projections of three-
# dimensional objects by way of line drawings has escalated in recent years. tained in a grid block, Bi , If an element Aj is entirely con-
# an index i, which represents the grid block, is placed in
# E..’ 1 If, however, some part of the element belongs to the boundary boxes of four or
# less blocks and is not a proper subset of any block, then i will be k
# i = 1 Ls * base ‘-’
# s=l
# where
# l<k<4
# Ls = the grid block number involved
# base = log2 N + constant + 1
# This value of i is also placed in E.. :,+ ‘..?,.i ‘..‘2 I.+..+ *.t,+ L RWLlR
# Water tower Array of planes
# 73 polygons 171 polygons
# Execution time = 10 set Execution time = 60 set Stability derivative plot
# 625 polygons
# Execution time = 60 set
# Modified F-16
# 159 polygons
# Execution time = 12.5 set
# Intersecting planes
# 20 polygons
# Execution time = 1.8 set Box with a hole
# 6 polygons,
# Execution time = .35 set
# 11 APPENDIX C
# STEPS OF THE ALGORITHM
# The sequence of the programmed algorithm is presented in the following
# discussion.
#
# ===Keyword list===
# respect              14
# c                    12
# boundary             12
# plane                11
# visible              11
# pi                    9
# interior              9
# z                     8
# points                8
# number                7
# general solution      6
# x                     6
# point                 6
# visibility            6
# ai                    6
# pil                   6
# relevant elements     5
# p                     5
# projection            5
# element               5
# dtype: int64
#
# ===Keyword Frequency plot===

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import PyPDF2 as PyPDF2
import nltk
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize, sent_tokenize
import string
from rake_nltk import Rake
import pandas as pd


#================Summary===========================
mypdf = open("corpus/19940008413.pdf", mode='rb')
pdfReader = PyPDF2.PdfFileReader(mypdf)
text=''
for i in range(0,pdfReader.numPages):
    # creating a page object
    pageObj = pdfReader.getPage(i)
    # extracting text from page
    text=text+pageObj.extractText()
#tokenize
stopWords = set (stopwords.words("english"))
words = word_tokenize(text)
#frequency table
freqTable = dict()
for word in words:
    word = word.lower()
    if word in stopWords:
        continue
    if word in freqTable:
        freqTable[word] +=1
    else:
        freqTable[word] =1
#store sentences
sentences = sent_tokenize(text)
sentenceValue = dict()
for sentence in sentences:
    for word, freq in freqTable.items():
        if word in sentence.lower():
            if sentence in sentenceValue:
                sentenceValue[sentence] +=1
            else:
                sentenceValue[sentence] =1

sumValues = 0
for sentence in sentenceValue:
    sumValues += sentenceValue[sentence]
average = int(sumValues / len(sentenceValue))
#store sentences in summary
summary = ''
for sentence in sentences:
    if (sentence in sentenceValue) and (sentenceValue[sentence] > (2 * average)):
        summary += " " + sentence
print()
print("====This is the Summary===")
print(summary)
#================Keywords===========================
rake_nltk_var = Rake()
#remove punctuation
text = text.translate(str.maketrans('', '', string.punctuation))
#rake
rake_nltk_var.extract_keywords_from_text(text)
keyword_extracted = rake_nltk_var.get_ranked_phrases()
# Creating FreqDist with 20 most common tokens
all_fdist = nltk.FreqDist(keyword_extracted).most_common(20)

# Convert to Pandas for plotting
all_fdist = pd.Series(dict(all_fdist))

## Setting figure, ax into variables
fig, ax = plt.subplots(figsize=(10,30))

print()
print("===Keyword list===")
print(all_fdist)

#================Keywords Frequency plot===========================
print()
print("===Keyword Frequency plot===")
## Seaborn plotting using Pandas attributes + xtick rotation for ease of viewing
all_plot = sns.barplot(y=all_fdist.index, x=all_fdist.values, ax=ax)
plt.xticks(rotation=30);
# Out:
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# ====This is the Summary===
#  P osenau
# NASA Langley Researc h Cen ter
# Hampton/, Virginia
# m/.a/.k/.p osenau/@larc/.nasa/.go v
# Abstract
# In aerospace computational /#0Duid dynamics calculations/, high asp ect ratio/, or stretc hed/,
# triangulations are often used to adequately resolv e the features of a viscous /#0Do w around
# b o dies/. /4 An alternativ e approac h
# Another w a y in whic h the triangulation/#2Fcon v ex h ull approac h migh t b e mo di/#0Ced is b yc hang/-
# ing the pro jection metho d used to lift the p oin ts to the b o dy /.P ersp ectiv e pro jection along
# the line connecting the pro jection p oin t/#28 /0 /; /0 /;z
# pr oj/#29/, /#28 x/; y /; /0/#29/, and a con v ex b o dy is used in/-
# stead of orthogonal pro jection/. z /=/1/4/0
# /@
# /,z
# pr oj
# px/2
# /+ y/2/,s
# /4 z
# pr oj/+z/2
# pr oj
# x/2
# /+ y/2/1
# A/2
# /5 Discussion of Figures
# In this section w e discuss sev eral examples of the v ariation in circumshap e for triangulations
# deriv ed from either con v ex b o dy alternativ es to the parab oloid/, or alternativ e pro jection/. /#28a/#29 z
# p/#3E /0/; /#28b/#29 z
# p/#3C /0
# A Deriv ation of P ersp ectiv e Pro jection Circumshap e F unc/-
# tion
# Giv en the equations for a parab oloid/, z/0
# /= x/0 /2
# /+ y/0 /2
# /, a plane/, z/0
# /= ax/0
# /+ by/0
# /+ c /, and a pro jection
# p oin t/#28 /0 /; /0 /;z
# p/#29/, the circumshap es on the /2D plane can b e determined in the follo wing manner/. The goal is to /#0Cnd an expression f /#28 x /#29/= x/0
# suc h that g /#28 x/0
# /#29/= x/0 /2
# /,o r g /#28 f /#28 x /#29/#29 /= x/0 /2
# /.F rom
# consideration of similar triangles/:
# /, z
# pr ojx/= /,x/0 /2
# /, z
# pr oj
# x/0
# Rearranging in terms of x/0
# giv es/:
# x/0 /2
# /+z
# pr ojxx/0
# /, z
# pr oj/=/0
# Solving for x/0
# yields f /#28 x /#29/:
# f /#28 x /#29/= x/0
# /=/1/2/2
# /4/, z
# pr oj
# x/#06s
# z/2
# pr ojx/2/+/4 z
# pr oj/3
# /5
# and g /#28 f /#28 x /#29/#29 is
# g /#28 f /#28 x /#29/#29 /= x/0 /2
# /=/1/4/2
# /4/, z
# pr oj
# x/#06s
# z/2
# pr ojx/2/+/4 z
# pr oj/3
# /5/2
# Because the parab oloid is circularly symmetric ab out the z /-axis/, it ma y b e observ ed that
# b y lo oking at planes through the z /-axis/, the /3D problem is iden tical to the /2D problem/. /1/1-1 -0.5 0.5 1
# -1-0.50.51Figure /5a/: Circumshap es deriv ed from parab oloid x/2
# /+ y/2Figure /5b/: T riangulation deriv ed from parab oloid x/2
# /+ y/2
# /1/2-1 -0.5 0.5 1
# -1-0.50.51Figure /6a/: Circumshap es deriv ed from x/2
# /+/1 /0 y/2
# /, /#0E /=/0 /: /0/5Figure /6b/: T riangulation deriv ed from x/2
# /+/1 /0 y/2
# /1/3-1 -0.5 0.5 1
# -1-0.50.51Figure /7a/: Circumshap es deriv ed from x/2
# /+ y/4
# /, /#0E /=/0 /: /0/2Figure /7b/: T riangulation deriv ed from x/2
# /+ y/4
# /1/4-1 -0.5 0.5 1
# -1-0.50.51Figure /8a/: Circumshap es deriv ed from x/4
# /+ y/4
# /, /#0E /=/0 /: /0/2Figure /8b/: T riangulation deriv ed from x/4
# /+ y/4
# /1/50.5 1 1.5 2 2.50.511.522.5Figure /9a/: Circumshap es deriv ed from x/3
# /+ y/3
# /, /#0E /=/0 /: /0/9Figure /9b/: T riangulation deriv ed from x/3
# /+ y/3
# /1/60.5 1 1.5 2 2.50.511.522.5Figure /1/0a/: Circumshap es deriv ed from x/1 /: /5
# /+ y/1 /: /5
# /, /#0E /=/0 /: /0/1/5Figure /1/0b/: T riangulation deriv ed from x/1 /: /5
# /+ y/1 /: /5
# /1/70.5 1 1.5 2 2.5
# 0.51.522.5Figure /1/1a/: Circumshap es deriv ed from x/1 /: /5
# /+/1 /0 y/1 /: /5
# /, /#0E /=/0 /: /0/1/5Figure /1/1b/: T riangulation deriv ed from x/1 /: /5
# /+/1 /0 y/1 /: /5
# /1/8-4 -2 2 4
# -3-2-1123Figure /1/2a/: Circumshap es deriv ed from triangulation in Figure /1/2bFigure /1/2b/: T riangulation deriv ed from z /=/1
# /4/#20
# /,z
# pr oj
# px/2
# /+ y/2/,r
# /4 z
# pr oj/+z/2
# pr oj
# x/2
# /+ y/2/!
#
# ===Keyword list===
# p oin                    10
# triangulation            10
# f 28 x                    9
# riangulation deriv ed     9
# b                         8
# plane                     8
# used                      7
# metho                     7
# delauna                   7
# circumshap es             6
# 2d plane                  6
# plotted                   6
# distance                  5
# con v ex h ull            4
# con v e x bod             4
# con v ex b                4
# p oin ts                  4
# parab oloid               4
# dy                        4
# tersection                4
# dtype: int64
#
# ===Keyword Frequency plot===

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import PyPDF2 as PyPDF2
import nltk
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize, sent_tokenize
import string
from rake_nltk import Rake
import pandas as pd


#================Summary===========================
mypdf = open("corpus/19890016299.pdf", mode='rb')
pdfReader = PyPDF2.PdfFileReader(mypdf)
text=''
for i in range(0,pdfReader.numPages):
    # creating a page object
    pageObj = pdfReader.getPage(i)
    # extracting text from page
    text=text+pageObj.extractText()
#tokenize
stopWords = set (stopwords.words("english"))
words = word_tokenize(text)
#frequency table
freqTable = dict()
for word in words:
    word = word.lower()
    if word in stopWords:
        continue
    if word in freqTable:
        freqTable[word] +=1
    else:
        freqTable[word] =1
#store sentences
sentences = sent_tokenize(text)
sentenceValue = dict()
for sentence in sentences:
    for word, freq in freqTable.items():
        if word in sentence.lower():
            if sentence in sentenceValue:
                sentenceValue[sentence] +=1
            else:
                sentenceValue[sentence] =1

sumValues = 0
for sentence in sentenceValue:
    sumValues += sentenceValue[sentence]
average = int(sumValues / len(sentenceValue))
#store sentences in summary
summary = ''
for sentence in sentences:
    if (sentence in sentenceValue) and (sentenceValue[sentence] > (3 * average)):
        summary += " " + sentence
print()
print("====This is the Summary===")
print(summary)
#================Keywords===========================
rake_nltk_var = Rake()
#remove punctuation
text = text.translate(str.maketrans('', '', string.punctuation))
#rake
rake_nltk_var.extract_keywords_from_text(text)
keyword_extracted = rake_nltk_var.get_ranked_phrases()
# Creating FreqDist with 20 most common tokens
all_fdist = nltk.FreqDist(keyword_extracted).most_common(20)

# Convert to Pandas for plotting
all_fdist = pd.Series(dict(all_fdist))

## Setting figure, ax into variables
fig, ax = plt.subplots(figsize=(10,30))

print()
print("===Keyword list===")
print(all_fdist)

#================Keywords Frequency plot===========================
print()
print("===Keyword Frequency plot===")
## Seaborn plotting using Pandas attributes + xtick rotation for ease of viewing
all_plot = sns.barplot(y=all_fdist.index, x=all_fdist.values, ax=ax)
plt.xticks(rotation=30);
# Out:
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# ====This is the Summary===
#  NASA Technical Memorandum 1021 10
# Acoustic Propagation in Curved Ducts With Extended Reacting Wall Treatment
# Kenneth J. Baumeister
# Lewis Research Center Cleveland,
# Ohio
# c Prepared for the 1989 Winter Annual Meeting
# of the American Society
# of Mechanical Engineers San Francisco, California, December
# 10- 15, 1989 C
# ABSTRACT
# Af
# emp 1 oyed propagat absorb
# i n ACOUSTIC PROPAGATION IN CURVED DUCTS WITH EXTENDED REACTING WALL TREATMENT Kenneth
# J. Baumeister National Aeronautics and Space Administration Lewis Research Center Cleveland, Ohio 44135
# nite-element Galerkin formulation has been to study the attenuation
# of acoustic waves ng in two-dimensional S-curved ducts with walls without a mean
# flow. (10)
# b' characteristic duct height ba
# c;
# E
# f
# h
# i
# L
# NX -
# n
# P
# P
# T
# t
# X
# Y
# a
# a
# E
# x
# LJ
# PO
# w
# 0' dimensionless entrance height, b;/b' adiabatic speed of sound acoustic power dimensionless frequency, f'b;/cda
# = b'/X' dimensionless duct offset height, h'/b; a oa
# J-'
# dimensionless length, L'bi grid points in the axial direction outward unit normal
# 12 dimens ion1 ess acous t i c pressure, P' (x ,y, t )/phacoa dimensionless pressure, P(x,y,t)/e dimensionless thickness of absorber wall, T'/b; dimensionless time, t'cAa/bi dimensionless axial distance, x'/b;
# iwt
# dimens dimens dimens dimens dimens onless onless onless dimensionless dimensionless dimensionless angular veloc onless transverse distance, y'/b; onless attenuation constant, Eq. As developed by Baumeister and Dah1 (1987),
# for harmonic pressure propagation (,+!Ut)
# in the heterogeneous absorber material, the equations The S-curve defined A positive going
# The assumed known pressure waves propagating down
# The acoustic propagation through the
# two-
# 2 c of state, continuity, and momentum were combined to yield the following wave equation in dimensionless
# form:
# The usual symbols for acoustic propagation are employed and all are explicitly defined in the nomenclature. Again, using the momentum equations to relate the acoustic velocity to the pressure fields requires
# -
# VD*~=O (4) In addition, recall that a model solution (Morse and Ingard 1968, p. 504)
# is used to represent the pres- sure in the semi-infinite, hard wall entrance and
# exit
# regions while a finite-element solution is used to gen- erate the solution in the curved portion of the duct. (3) reduces to For plane waves propagating in a homogeneous lossy The solution of which can be written as
# -ax -iBx p=e e
# where
# RI A = clpR + E p
# RR I1 B=cp -cp (6)
# (7)
# (8)
# (9) (10)
# The superscripts R and I stand for real and imaginary parts and the wavelength can be expressed in terms
# of the propagation phase constant 13 as follows: 2n
# A= - B (11) The number of grid points
# Nx In the axial direction
# to accurately resolve the acoustic field is
# 12L 6RL N =-=- xx n (12) For the special case where the duct length
# is just equal to the axial wavelength of the acoustic wave, 12 nodal points are required in the axial direction.
#
# ===Keyword list===
# duct                  16
# examined              12
# number                10
# curved duct            9
# sound                  9
# shown                  9
# seen                   9
# found                  9
# fig 12                 7
# p                      6
# fig 3                  6
# e                      6
# used                   6
# determined             6
# absorber thickness     5
# curved ducts           5
# duct length            5
# attenuation            5
# acoustical society     5
# entrance               5
# dtype: int64
#
# ===Keyword Frequency plot===
